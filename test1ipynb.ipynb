# %% [markdown]
# <a href="https://colab.research.google.com/github/marlin272003/crunchix/blob/main/test1ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install textblob

from textblob import TextBlob
from google.colab import files

# Function to analyze sentiment
def analyze_sentiment(text):

    # Create a TextBlob object
    blob = TextBlob(text)

    # Get sentiment polarity (-1 to 1)
    polarity = blob.sentiment.polarity

    # Determine sentiment
    if polarity > 0:
        return "Positive"

    elif polarity == 0:
        return "Neutral"

    else:
        return "Negative"


# Upload text file
uploaded = files.upload()

# Get uploaded file name
file_name = list(uploaded.keys())[0]

# Counters
positive_count = 0
neutral_count = 0
negative_count = 0

# Read file and analyze each line
with open(file_name, "r", encoding="utf-8") as file:

    lines = file.readlines()

    for line in lines:

        # Remove spaces and empty lines
        text = line.strip()

        if text != "":

            sentiment = analyze_sentiment(text)

            print(f"Text: {text}")
            print(f"Sentiment: {sentiment}")
            print("-" * 50)

            # Count sentiments
            if sentiment == "Positive":
                positive_count += 1

            elif sentiment == "Neutral":
                neutral_count += 1

            else:
                negative_count += 1


# Print final results
print("\nFinal Results")
print(f"Positive Sentences: {positive_count}")
print(f"Neutral Sentences: {neutral_count}")
print(f"Negative Sentences: {negative_count}")
# Out:
# ...
#      <input type="file" id="files-4360c409-8184-48bc-9a04-6b924fd043a7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4360c409-8184-48bc-9a04-6b924fd043a7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
